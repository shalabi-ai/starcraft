# %%
# !pip install -e ..
# Out:
# Obtaining file:///home/mohammad/learn/starcraft/co-op/analyzer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: analyzer
#   Building editable for analyzer (pyproject.toml) ... done
#   Created wheel for analyzer: filename=analyzer-0.1.0-0.editable-py3-none-any.whl size=1180 sha256=25832ea573f3858a5c93d8b6627821d6b7a9607820388e5c411ed1adf5091ffd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fscnp_gz/wheels/80/68/03/98f7d7f72c71ba4eef83db7a82855e13aee68cd2747d293bb9
# Successfully built analyzer
# Installing collected packages: analyzer
#   Attempting uninstall: analyzer
#     Found existing installation: analyzer 0.1.0
#     Can't uninstall 'analyzer'. No files were found to uninstall.
# Successfully installed analyzer-0.1.0

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from replay.analyser_factory import AnalyserFactory

path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"
analyser= AnalyserFactory.create_analyser(path)

# %%
from reports.commanders import Commanders

commanders = Commanders(analyser)
commanders_data = commanders.commanders_report()
print(commanders_data)
# Out:
#    commander                           unit  kills
# 0    Abathur                  BiomassPickup    826
# 1    Abathur                      ToxicNest     98
# 2    Abathur                      RoachVile     18
# 3    Abathur                         Locust    272
# 4    Abathur                 RavagerAbathur    189
# 5    Abathur                   LocustFlying     15
# 6    Abathur                      SwarmHost   1740
# 7       Nova                Marine_BlackOps     48
# 8       Nova                    NovaBoombot    125
# 9       Nova       NovaDefensiveMatrixDrone      6
# 10      Nova                       NovaCoop    131
# 11      Nova              Marauder_BlackOps     15
# 12      Nova               Goliath_BlackOps     25
# 13      Nova                HellbatBlackOps     44
# 14      Nova  NovaGriffinBombingRunTargeter      3

# %%
commanders.plot_commanders_chart()
