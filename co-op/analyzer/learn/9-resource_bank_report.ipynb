# %%
#!pip uninstall s2protocol
#!pip install git+https://github.com/shalabi-ai/s2protocol

# %%
# !pip install -e ..
# Out:
# Obtaining file:///home/mohammad/learn/starcraft/co-op/analyzer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: analyzer
#   Building editable for analyzer (pyproject.toml) ... done
#   Created wheel for analyzer: filename=analyzer-0.1.0-0.editable-py3-none-any.whl size=1180 sha256=951772560797c8678c15ccbdc84f26c81d43eb4f0812017ad836311d0f31d938
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xks7giir/wheels/80/68/03/98f7d7f72c71ba4eef83db7a82855e13aee68cd2747d293bb9
# Successfully built analyzer
# Installing collected packages: analyzer
#   Attempting uninstall: analyzer
#     Found existing installation: analyzer 0.1.0
#     Can't uninstall 'analyzer'. No files were found to uninstall.
# Successfully installed analyzer-0.1.0

# %%
import sc2reader
from replay.replay import CoOpReplay
from reports.resources.resource_bank import ResourceBankReport
from replay.replay_factory import ReplayFactory

file_path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"

replay2 = sc2reader.load_replay(file_path)
coopReplay = CoOpReplay(replay2)
players = coopReplay.getPlayers()

tracker_events = ReplayFactory.replay_from_s2protocol(file_path)
report = ResourceBankReport(tracker_events)
report.generate_report(players)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 14
#      10 players = coopReplay.getPlayers()
#      11
#      12 tracker_events = ReplayFactory.replay_from_s2protocol(file_path)
#      13 report = ResourceBankReport(tracker_events)
# ---> 14 report.generate_report(players)
#
# File ~/learn/starcraft/co-op/analyzer/src/co_op/reports/resources/economy_report.py:14, in EconomyReport.generate_report(self, players)
#      13 def generate_report(self, players: list[Player]):
# ---> 14     fig, axes = plt.subplots(
#      15         1,
#      16         len(players),
#      17         figsize=(8 * (len(players) + 1), 7)
#      18     )
#      19     if len(players) == 1:
#      20         axes = [axes]
#
# File ~/anaconda3/envs/ai/lib/python3.13/site-packages/matplotlib/pyplot.py:1777, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1632 """
#    1633 Create a figure and a set of subplots.
#    1634
#    (...)   1774
#    1775 """
#    1776 fig = figure(**fig_kw)
# -> 1777 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1778                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1779                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1780                    width_ratios=width_ratios)
#    1781 return fig, axs
#
# File ~/anaconda3/envs/ai/lib/python3.13/site-packages/matplotlib/figure.py:919, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     916     gridspec_kw['width_ratios'] = width_ratios
#     918 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 919 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     920                   subplot_kw=subplot_kw)
#     921 return axs
#
# File ~/anaconda3/envs/ai/lib/python3.13/site-packages/matplotlib/gridspec.py:284, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     281         subplot_kw["sharex"] = shared_with[sharex]
#     282         subplot_kw["sharey"] = shared_with[sharey]
#     283         axarr[row, col] = figure.add_subplot(
# --> 284             self[row, col], **subplot_kw)
#     286 # turn off redundant tick labeling
#     287 if sharex in ["col", "all"]:
#
# File ~/anaconda3/envs/ai/lib/python3.13/site-packages/matplotlib/gridspec.py:241, in GridSpecBase.__getitem__(self, key)
#     239     except ValueError as err:
#     240         raise ValueError("Unrecognized subplot spec") from err
# --> 241     num1, num2 = np.ravel_multi_index(
#     242         [_normalize(k1, nrows, 0), _normalize(k2, ncols, 1)],
#     243         (nrows, ncols))
#     244 else:  # Single key
#     245     num1, num2 = _normalize(key, nrows * ncols, None)
#
# KeyboardInterrupt:
