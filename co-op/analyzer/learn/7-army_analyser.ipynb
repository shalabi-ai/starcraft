# %%
# !pip install -e ..
# Out:
# Obtaining file:///home/mohammad/learn/starcraft/co-op/analyzer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: analyzer
#   Building editable for analyzer (pyproject.toml) ... done
#   Created wheel for analyzer: filename=analyzer-0.1.0-0.editable-py3-none-any.whl size=1180 sha256=69f7ea8998967522185dc9be73a9261d7bc861e21186a9169f0eafb35f8ae28d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w9j0kqdc/wheels/80/68/03/98f7d7f72c71ba4eef83db7a82855e13aee68cd2747d293bb9
# Successfully built analyzer
# Installing collected packages: analyzer
#   Attempting uninstall: analyzer
#     Found existing installation: analyzer 0.1.0
#     Can't uninstall 'analyzer'. No files were found to uninstall.
# Successfully installed analyzer-0.1.0

# %%
from replay.analyser_factory import AnalyserFactory

path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"
army_analyser = AnalyserFactory.create_army_analyser(path)
df = army_analyser.army_state_timeline()
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from replay.analyser_factory import AnalyserFactory
#       2
#       3 path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"
# ----> 4 army_analyser = AnalyserFactory.create_army_analyser(path)
#       5 df = army_analyser.army_state_timeline()
#       6 print(df)
#
# File ~/learn/starcraft/co-op/analyzer/src/co_op/replay/analyser_factory.py:31, in AnalyserFactory.create_army_analyser(path)
#      28 players = coopReplay.getPlayerMap()
#      30 army_processor = ArmyProcessor(replay1)
# ---> 31 units, units_events = army_processor.process_replay()
#      33 analyser = ArmyAnalyser(units_events, players)
#      34 return analyser
#
# File ~/learn/starcraft/co-op/analyzer/src/co_op/replay/army_processor.py:43, in ArmyProcessor.process_replay(self)
#      40 unit_events = []
#      42 for event in self.replay.tracker_events:
# ---> 43     seconds = self.frame_to_seconds(event.frame)
#      45     # -------------------------
#      46     # Unit Created
#      47     # -------------------------
#      48     if event.name in (
#      49             "UnitBornEvent",
#      50             "UnitInitEvent"
#      51     ):
#
# File ~/learn/starcraft/co-op/analyzer/src/co_op/replay/army_processor.py:34, in ArmyProcessor.frame_to_seconds(self, frame)
#      31 def __init__(self, replay: Replay):
#      32     self.replay = replay
# ---> 34 def frame_to_seconds(self, frame):
#      35     return frame / self.FRAME_RATE
#      37 def process_replay(self):
#
# File ~/.local/share/JetBrains/IntelliJIdea2026.1/python-ce/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py:365, in ThreadTracer.__call__(self, frame, event, arg)
#     362         self._args = args
#     363 # ENDIF
# --> 365     def __call__(self, frame, event, arg):
#     366         ''' This is the callback used when we enter some context in the debugger.
#     367
#     368         We also decorate the thread we are in with info about the debugging.
#    (...)    376             This is the global debugger (this method should actually be added as a method to it).
#     377         '''
#     378         # IFDEF CYTHON
#     379         # cdef str filename;
#     380         # cdef str base;
#    (...)    387         # ENDIF
#     388         # print('ENTER: trace_dispatch', frame.f_code.co_filename, frame.f_lineno, event, frame.f_code.co_name)
#
# KeyboardInterrupt:

# %%
army_size_df = (
    df
    .groupby(["time", "commander"])
    .agg(size=("count", "sum"))
    .reset_index()
)
print(army_size_df)
# Out:
#     time commander  size
# 0      0      Nova     1
# 1     30   Abathur    16
# 2     30      Nova     4
# 3     60   Abathur    18
# 4     60      Nova     5
# ..   ...       ...   ...
# 66   990      Nova    30
# 67  1020   Abathur   339
# 68  1020      Nova    30
# 69  1050   Abathur   227
# 70  1050      Nova    30
#
# [71 rows x 3 columns]

# %%
snapshot = df[
    (df["commander"] == "Abathur")
    & (df["time"] == 1020)
    ]

print(
    snapshot.sort_values(
        "count",
        ascending=False
    )
)
# Out:
#      time  player commander             unit_type  count
# 536  1020       1   Abathur                Locust    111
# 531  1020       1   Abathur             ToxicNest     83
# 532  1020       1   Abathur         BiomassPickup     50
# 535  1020       1   Abathur             SwarmHost     36
# 529  1020       1   Abathur              Overlord     28
# 528  1020       1   Abathur                 Larva     18
# 537  1020       1   Abathur          LocustFlying      7
# 534  1020       1   Abathur        RavagerAbathur      3
# 527  1020       1   Abathur  ACHeroSpawnPlacement      1
# 533  1020       1   Abathur             RoachVile      1
# 530  1020       1   Abathur     CoopCasterAbathur      1
