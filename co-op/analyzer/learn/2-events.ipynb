# %%
# !pip install -e ..
# Out:
# Obtaining file:///home/mohammad/learn/starcraft/co-op/analyzer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for analyzer (pyproject.toml) ... done
#   Created wheel for analyzer: filename=analyzer-0.1.0-0.editable-py3-none-any.whl size=1180 sha256=4c365f73a407e7e9d0d105626ae9ffeddd564fb4b7fdb5137067bd7aeebfe10f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5_1rfvt/wheels/80/68/03/98f7d7f72c71ba4eef83db7a82855e13aee68cd2747d293bb9
# Successfully built analyzer
# ...
#   Attempting uninstall: analyzer
#     Found existing installation: analyzer 0.1.0
#     Can't uninstall 'analyzer'. No files were found to uninstall.
# ...

# %%
# !pip install sc2reader

# %%
from replay.replay import CoOpReplay
import sc2reader


replay1 = sc2reader.load_replay("/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay")

print(replay1.map_name)
print(replay1.length)
coopReplay = CoOpReplay(replay1)
players = coopReplay.getPlayers()
#print(players)
# Out:
# Chain of Ascension
# 17.48

# %%
from event import CoOpEvent

events = CoOpEvent(replay1.events)
event_types = events.get_event_types()
print(event_types)
# Out:
# {'GameEvent': {'UnitDoneEvent', 'UpgradeCompleteEvent', 'AddToControlGroupEvent', 'SelectionEvent', 'CameraEvent', 'CommandManagerStateEvent', 'TargetUnitCommandEvent', 'UserOptionsEvent', 'TargetPointCommandEvent', 'PlayerLeaveEvent', 'ChatEvent', 'UnitTypeChangeEvent', 'BasicCommandEvent', 'SetControlGroupEvent', 'ProgressEvent', 'DataCommandEvent', 'UnitDiedEvent', 'UnitPositionsEvent', 'UpdateTargetPointCommandEvent', 'UpdateTargetUnitCommandEvent', 'GetControlGroupEvent', 'PlayerSetupEvent', 'PlayerStatsEvent'}, 'PlayerEvent': {'UnitBornEvent', 'UnitInitEvent'}}

# %% [markdown]
# ## Get player1 events

# %%
from event import CoOpEvent

events = CoOpEvent(replay1.tracker_events)
events_dict = events.arrange_events()
#for event in events_dict[players[0].id]:
 #   print(event)

unit_born_events = events.get_unit_born_events_for_player(players[1].id)
for event in unit_born_events:
    print(event)
# Out:
# 00.00	 Player 2 - mshalabi (Terran) - Unit born None [D80001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born CommandCenter [67C0001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6800001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6840001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6880001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [68C0001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6900001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6940001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6980001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [69C0001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6A00001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6A40001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6A80001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born SCV [6AC0001]
# 00.00	 Player 2 - mshalabi (Terran) - Unit born None [6B00001]
# ...

# %%
from event import CoOpEvent

events = CoOpEvent(replay1.events)
unit_born_events = events.get_unit_born_events()
for event in unit_born_events:
    print(event)
# Out:
# 00.00	            None - Unit born MineralField [1]
# 00.00	            None - Unit born MineralField [40001]
# 00.00	            None - Unit born MineralField [80001]
# 00.00	            None - Unit born MineralField [C0001]
# 00.00	            None - Unit born MineralField [100001]
# 00.00	            None - Unit born MineralField [140001]
# 00.00	            None - Unit born MineralField [180001]
# 00.00	            None - Unit born VespeneGeyser [1C0001]
# 00.00	            None - Unit born VespeneGeyser [200001]
# 00.00	            None - Unit born MineralField [240001]
# 00.00	 Player 4 - Amon's Forces (Zerg) - Unit born SpineCrawler [280001]
# 00.00	            None - Unit born MineralField [2C0001]
# 00.00	            None - Unit born MineralField [300001]
# 00.00	 Player 3 - Amon's Forces (Zerg) - Unit born None [340001]
# 00.00	 Player 3 - Amon's Forces (Zerg) - Unit born SpineCrawler [380001]
# 00.00	 Player 3 - Amon's Forces (Zerg) - Unit born SpineCrawler [3C0001]
# ...

# %%
for event in replay1.tracker_events:
    print(event)
# Out:
# 00.00	 PlayerSetupEvent
# 00.00	 PlayerSetupEvent
# 00.00	 PlayerSetupEvent
# 00.00	 PlayerSetupEvent
# 00.00	 PlayerSetupEvent
# 00.00	 PlayerSetupEvent
# 00.00	 PlayerSetupEvent
# 00.00	 PlayerSetupEvent
# 00.00	 PlayerSetupEvent
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceOverlord upgrade completed
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceStalker upgrade completed
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceGhost upgrade completed
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceColossus upgrade completed
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceRoach upgrade completed
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceOracle upgrade completed
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceMule upgrade completed
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceViking upgrade completed
# 00.00	 Player 1 - Partykeeper (Zerg) - RewardDanceInfestor upgrade completed
# 00.00	            None - Unit born MineralField [1]
# ...
