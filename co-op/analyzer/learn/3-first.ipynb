# %%
# !pip install -e ..
# Out:
# Obtaining file:///home/mohammad/learn/starcraft/co-op/analyzer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: analyzer
#   Building editable for analyzer (pyproject.toml) ... done
#   Created wheel for analyzer: filename=analyzer-0.1.0-0.editable-py3-none-any.whl size=1180 sha256=7cce9a23b20b72fdf390cf2c94725a11f180734e45827409672ba7b165eb1d42
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ph3shyyk/wheels/80/68/03/98f7d7f72c71ba4eef83db7a82855e13aee68cd2747d293bb9
# Successfully built analyzer
# Installing collected packages: analyzer
#   Attempting uninstall: analyzer
#     Found existing installation: analyzer 0.1.0
#     Can't uninstall 'analyzer'. No files were found to uninstall.
# Successfully installed analyzer-0.1.0

# %%
# !pip install s2protocol
# Out:
# Requirement already satisfied: s2protocol in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (5.0.15.95299.0)
# Requirement already satisfied: mpyq>=0.2.2 in /home/mohammad/anaconda3/envs/ai/lib/python3.13/site-packages (from s2protocol) (0.2.5)

# %%
import sc2reader
from replay.processor import ReplayProcessor

#path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/tychus/Lock & Load-750-protos-ground.SC2Replay"
path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"
replay1 = sc2reader.load_replay(path)
processor = ReplayProcessor(replay1)
kills, kill_events = processor.process_replay()
processor.print_kills(kills)
# Out:
# Player 5
#   Scourge: 11
#   InfestedAbomination: 8
#   Zergling: 8
#   Roach: 6
#   BanelingBurrowed: 5
#   BroodlingEscort: 4
#   SpineCrawler: 3
#   Baneling: 3
#   LurkerBurrowed: 2
#   Corruptor: 2
#   UltraliskBurrowed: 1
#   Mutalisk: 1
#
# Player 1
#   SwarmHost: 1740
#   BiomassPickup: 826
#   Locust: 272
#   RavagerAbathur: 189
#   ToxicNest: 98
#   RoachVile: 18
#   LocustFlying: 15
#
# Player 6
#   HybridDominatorVoid: 28
#   HybridReaver: 12
#   Guardian: 9
#   HybridNemesis: 9
#   Mutalisk: 8
#   Scourge: 7
#   Devourer: 5
#   Zergling: 4
#   BanelingBurrowed: 4
#   LurkerBurrowed: 4
#   BroodlingEscort: 4
#   SpineCrawler: 3
#   UltraliskBurrowed: 3
#   Hydralisk: 2
#   InfestedAbomination: 1
#   Baneling: 1
#   Ultralisk: 1
#
# Player 3
#   Mutalisk: 10
#   Scourge: 10
#   Zergling: 3
#   SpineCrawler: 3
#   Devourer: 2
#   LurkerBurrowed: 2
#   Roach: 1
#
# Player 2
#   NovaCoop: 131
#   NovaBoombot: 125
#   Marine_BlackOps: 48
#   HellbatBlackOps: 44
#   Goliath_BlackOps: 25
#   Marauder_BlackOps: 15
#   NovaDefensiveMatrixDrone: 6
#   NovaGriffinBombingRunTargeter: 3
#
# Player 4
#   SpineCrawler: 6
#   Scourge: 4
#   Ultralisk: 4
#   Devourer: 3
#   Mutalisk: 3
#   Zergling: 2
#   Roach: 2
#   InfestedAbomination: 2
#   Hydralisk: 2
#   SporeCrawler: 1
#   Guardian: 1
#
# Player 10
#   SlaynElemental: 55
#
# Player 8
#   PitAlarak: 1
