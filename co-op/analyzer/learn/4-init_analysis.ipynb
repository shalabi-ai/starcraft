# %%
# !pip install -e ..
# Out:
# Obtaining file:///home/mohammad/learn/starcraft/co-op/analyzer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for analyzer (pyproject.toml) ... done
#   Created wheel for analyzer: filename=analyzer-0.1.0-0.editable-py3-none-any.whl size=1180 sha256=d2b8375ef8ab646bd1a815f8d889327656784713ac3c4bfe73884f8e90c01b4a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e9fr3w5r/wheels/80/68/03/98f7d7f72c71ba4eef83db7a82855e13aee68cd2747d293bb9
# Successfully built analyzer
# ...
#   Attempting uninstall: analyzer
#     Found existing installation: analyzer 0.1.0
#     Can't uninstall 'analyzer'. No files were found to uninstall.
# ...

# %%
from replay.analyser import ReplayAnalyser
from replay.processor import ReplayProcessor
from replay.replay import CoOpReplay
import sc2reader
#path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/tychus/Lock & Load-750-protos-ground.SC2Replay"
path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"
replay1 = sc2reader.load_replay(path)

coopReplay = CoOpReplay(replay1)
players = coopReplay.getPlayerMap()

processor = ReplayProcessor(replay1)
kills, kill_events = processor.process_replay()

analyser = ReplayAnalyser(players, kills, kill_events)
print(analyser.top_units())
# Out:
# [(('SwarmHost', 1), 1740), (('BiomassPickup', 1), 826), (('Locust', 1), 272), (('RavagerAbathur', 1), 189), (('NovaCoop', 2), 131), (('NovaBoombot', 2), 125), (('ToxicNest', 1), 98), (('SlaynElemental', 10), 55), (('Marine_BlackOps', 2), 48), (('HellbatBlackOps', 2), 44), (('HybridDominatorVoid', 6), 28), (('Goliath_BlackOps', 2), 25), (('RoachVile', 1), 18), (('LocustFlying', 1), 15), (('Marauder_BlackOps', 2), 15), (('HybridReaver', 6), 12), (('Scourge', 5), 11), (('Mutalisk', 3), 10), (('Scourge', 3), 10), (('Guardian', 6), 9)]

# %%
print(analyser.top_victims())
# Out:
# [(('Locust', 1), 1740), (('BiomassPickup', 1), 826), (('Zergling', 1), 244), (('Zergling', 2), 139), (('Broodling', 1), 102), (('Mutalisk', 1), 66), (('Locust', 6), 58), (('SpineCrawler', 2), 29), (('Roach', 2), 28), (('SlaynElementalGrabAOEGroundUnit25', 10), 27), (('ToxicNest', 1), 25), (('Mutalisk', 2), 25), (('Locust', 5), 21), (('Hydralisk', 2), 20), (('LocustFlying', 6), 20), (('Scourge', 2), 19), (('Locust', 4), 19), (('Devourer', 1), 16), (('SlaynElementalGrabAOEGroundUnit150', 10), 15), (('SpineCrawler', 1), 13)]

# %%
print(analyser.commander_kills())
# Out:
# {'Abathur': 3158, 'Nova': 397}

# %%
print(analyser.commander_breakdown())
# Out:
# defaultdict(<function ReplayAnalyser.commander_breakdown.<locals>.<lambda> at 0x7078695af1a0>, {'Abathur': defaultdict(<class 'int'>, {'BiomassPickup': 826, 'ToxicNest': 98, 'RoachVile': 18, 'Locust': 272, 'RavagerAbathur': 189, 'LocustFlying': 15, 'SwarmHost': 1740}), 'Nova': defaultdict(<class 'int'>, {'Marine_BlackOps': 48, 'NovaBoombot': 125, 'NovaDefensiveMatrixDrone': 6, 'NovaCoop': 131, 'Marauder_BlackOps': 15, 'Goliath_BlackOps': 25, 'HellbatBlackOps': 44, 'NovaGriffinBombingRunTargeter': 3})})
