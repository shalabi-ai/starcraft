# %%
#!pip uninstall s2protocol
#!pip install git+https://github.com/shalabi-ai/s2protocol

# %%
# !pip install -e ..
# Out:
# Obtaining file:///home/mohammad/learn/starcraft/co-op/analyzer
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: analyzer
#   Building editable for analyzer (pyproject.toml) ... done
#   Created wheel for analyzer: filename=analyzer-0.1.0-0.editable-py3-none-any.whl size=1180 sha256=ff71e93941ea69e553d6a3618af2487660f758d2d8273bbff9a87fdd19f19d26
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fv5y0g9l/wheels/80/68/03/98f7d7f72c71ba4eef83db7a82855e13aee68cd2747d293bb9
# Successfully built analyzer
# Installing collected packages: analyzer
#   Attempting uninstall: analyzer
#     Found existing installation: analyzer 0.1.0
#     Can't uninstall 'analyzer'. No files were found to uninstall.
# Successfully installed analyzer-0.1.0

# %%
import sc2reader
from replay.replay import CoOpReplay
from reports.resources.commanders_economy import CommandersEconomyReport

file_path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"

replay2 = sc2reader.load_replay(file_path)
coopReplay = CoOpReplay(replay2)
players = coopReplay.getPlayers()

report = CommandersEconomyReport(file_path)
report.report(players)

# %%
from replay.replay_factory import ReplayFactory
from replay.economy_processor import EconomyProcessor
from reports.resources.commanders_economy import CommandersEconomyReport

file_path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"
replay1 = ReplayFactory.replay_from_s2protocol(file_path)

processor = EconomyProcessor(replay1)
df = processor.extract_player_stats(
    replay1,
    2
)
#df
CommandersEconomyReport.plot_income(df, "Tychus2")

replay1 = ReplayFactory.replay_from_s2protocol(file_path)
df = processor.extract_player_stats(
    replay1,
    1
)
#df
CommandersEconomyReport.plot_income(df, "Tychus1")

# %%
import sc2reader
from replay.replay import CoOpReplay
from reports.resources.commanders_economy import CommandersEconomyReport

file_path = "/home/mohammad/StarCraft II/Accounts/1176921989/2-S2-1-11021412/Replays/commanders/nova/abathur/Chain of Ascension-375.SC2Replay"

replay2 = sc2reader.load_replay(file_path)
coopReplay = CoOpReplay(replay2)
players = coopReplay.getPlayers()

report = CommandersEconomyReport(file_path)
report.show(players)
